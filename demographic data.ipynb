# %%
import pandas as pd
import os

# %%
#method 1:specify full path to file
#windows:
stats=pd.read_csv('F:\\notes\\sem-6\\termpaper\\DemographicData.csv')

# %%
stats
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 0                             Aruba          ABW      10.244        78.90000
# 1                       Afghanistan          AFG      35.253         5.90000
# 2                            Angola          AGO      45.985        19.10000
# 3                           Albania          ALB      12.877        57.20000
# 4              United Arab Emirates          ARE      11.044        88.00000
# 5                         Argentina          ARG      17.716        59.90000
# 6                           Armenia          ARM      13.308        41.90000
# 7               Antigua and Barbuda          ATG      16.447        63.40000
# 8                         Australia          AUS      13.200        83.00000
# 9                           Austria          AUT       9.400        80.61880
# 10                       Azerbaijan          AZE      18.300        58.70000
# ...

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
len(stats)
# Out:
# 195

# %%
len(stats.columns)
# Out:
# 5

# %%
stats.head(6)
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
# 5             Argentina          ARG      17.716            59.9
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income

# %%
stats.tail(6)
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 189             Samoa          WSM      26.172            15.3
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
#information on the colums
stats.info() #like str func in R
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
# Country Name      195 non-null object
# Country Code      195 non-null object
# Birth rate        195 non-null float64
# Internet users    195 non-null float64
# Income Group      195 non-null object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
# get stats on the columns
stats.describe() #like summary function in R
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
stats.describe().transpose()
# Out:
#                 count       mean        std  min      25%    50%      75%  \
# Birth rate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# Internet users  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                     max
# Birth rate      49.6610
# Internet users  96.5468

# %%
# renaming columns of a data frame

stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
stats.columns=['a','b','c','d','e']
stats.head()
# Out:
#                       a    b       c     d                    e
# 0                 Aruba  ABW  10.244  78.9          High income
# 1           Afghanistan  AFG  35.253   5.9           Low income
# 2                Angola  AGO  45.985  19.1  Upper middle income
# 3               Albania  ALB  12.877  57.2  Upper middle income
# 4  United Arab Emirates  ARE  11.044  88.0          High income

# %%
stats.columns=['Country Name', 'Country Code', 'Birth rate', 'Internet users',
       'Income Group']

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#subsetting dataframes in pandas

###three parts
#rows
#columns
#combine the two

# %%
#rows--
stats[21:26]
# Out:
#    Country Name Country Code  Birth rate  Internet users         Income Group
# 21       Belize          BLZ      23.092           33.60  Upper middle income
# 22      Bermuda          BMU      10.400           95.30          High income
# 23      Bolivia          BOL      24.236           36.94  Lower middle income
# 24       Brazil          BRA      14.931           51.04  Upper middle income
# 25     Barbados          BRB      12.188           73.00          High income

# %%
stats[21:] # 21 row to last
stats[:10] #first 10 rows
stats[ : :-1] #reverse the data frame
# Out:
#                                   a    b       c         d  \
# 194                        Zimbabwe  ZWE  35.715  18.50000
# 193                          Zambia  ZMB  40.471  15.40000
# 192                Congo, Dem. Rep.  COD  42.394   2.20000
# 191                    South Africa  ZAF  20.850  46.50000
# 190                     Yemen, Rep.  YEM  32.947  20.00000
# 189                           Samoa  WSM  26.172  15.30000
# 188              West Bank and Gaza  PSE  30.394  46.60000
# 187                         Vanuatu  VUT  26.739  11.30000
# 186                         Vietnam  VNM  15.537  43.90000
# 185           Virgin Islands (U.S.)  VIR  10.700  45.30000
# 184                   Venezuela, RB  VEN  19.842  54.90000
# 183  St. Vincent and the Grenadines  VCT  16.306  52.00000
# 182                      Uzbekistan  UZB  22.500  38.20000
# 181                   United States  USA  12.500  84.20000
# 180                         Uruguay  URY  14.374  57.69000
# ...

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats['Country Name']
# Out:
# 0                               Aruba
# 1                         Afghanistan
# 2                              Angola
# 3                             Albania
# 4                United Arab Emirates
# 5                           Argentina
# 6                             Armenia
# 7                 Antigua and Barbuda
# 8                           Australia
# 9                             Austria
# 10                         Azerbaijan
# 11                            Burundi
# 12                            Belgium
# 13                              Benin
# 14                       Burkina Faso
# 15                         Bangladesh
# 16                           Bulgaria
# 17                            Bahrain
# 18                       Bahamas, The
# 19             Bosnia and Herzegovina
# 20                            Belarus
# 21                             Belize
# 22                            Bermuda
# 23                            Bolivia
# 24                             Brazil
# ...

# %%
#combining rows and columns

stats[4:10][['Internet users','Birth rate']]
#stats[['Name','Ticket']][4:10] will be the same
# Out:
#    Internet users  Birth rate
# 4         88.0000      11.044
# 5         59.9000      17.716
# 6         41.9000      13.308
# 7         63.4000      16.447
# 8         83.0000      13.200
# 9         80.6188       9.400

# %%
df2= stats[['Internet users','Birth rate']]
df2[4:10]
# Out:
#    Internet users  Birth rate
# 4         88.0000      11.044
# 5         59.9000      17.716
# 6         41.9000      13.308
# 7         63.4000      16.447
# 8         83.0000      13.200
# 9         80.6188       9.400

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#basic operations with data frames
#already spoke about subset--- stats.head()

#mathamatical operations: 
result=stats["Internet users"] * stats["Birth rate"]
result.head()
# Out:
# 0    808.2516
# 1    207.9927
# 2    878.3135
# 3    736.5644
# 4    971.8720
# dtype: float64

# %%
# add a column:
stats['b*i']=result
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group       raj       b*i
# 0          High income  808.2516  808.2516
# 1           Low income  207.9927  207.9927
# 2  Upper middle income  878.3135  878.3135
# 3  Upper middle income  736.5644  736.5644
# 4          High income  971.8720  971.8720

# %%
#removing a column

stats=stats.drop('raj',axis=1) # axis =0 for rows,, 1for column
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group       b*i
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
stats=stats.drop('b*i',axis=1) # axis =0 for rows,, 1for column
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#filtering data frames

#filtering is about rows
stats["Birth rate"]>=15
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
# 5       True
# 6      False
# 7       True
# 8      False
# 9      False
# 10      True
# 11      True
# 12     False
# 13      True
# 14      True
# 15      True
# 16     False
# 17      True
# 18      True
# 19     False
# 20     False
# 21      True
# 22     False
# 23      True
# 24     False
# 25     False
# 26      True
# 27      True
# 28      True
# 29      True
#        ...
# 165     True
# 166     True
# 167     True
# 168     True
# 169    False
# 170     True
# 171     True
# 172     True
# 173     True
# 174    False
# 175     True
# 176     True
# 177     True
# 178     True
# 179    False
# 180    False
# 181    False
# 182     True
# 183     True
# 184     True
# 185    False
# 186     True
# 187     True
# 188     True
# 189     True
# 190     True
# 191     True
# 192     True
# 193     True
# 194     True
# Name: Birth rate, Length: 195, dtype: bool

# %%
fiter= stats["Birth rate"]>=1
fiter
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
#        ...
# 165    True
# 166    True
# 167    True
# 168    True
# 169    True
# 170    True
# 171    True
# 172    True
# 173    True
# 174    True
# 175    True
# 176    True
# 177    True
# 178    True
# 179    True
# 180    True
# 181    True
# 182    True
# 183    True
# 184    True
# 185    True
# 186    True
# 187    True
# 188    True
# 189    True
# 190    True
# 191    True
# 192    True
# 193    True
# 194    True
# Name: Birth rate, Length: 195, dtype: bool

# %%
stats.filter
# Out:
# <bound method NDFrame.filter of                        Country Name Country Code  Birth rate  Internet users  \
# 0                             Aruba          ABW      10.244        78.90000
# 1                       Afghanistan          AFG      35.253         5.90000
# 2                            Angola          AGO      45.985        19.10000
# 3                           Albania          ALB      12.877        57.20000
# 4              United Arab Emirates          ARE      11.044        88.00000
# 5                         Argentina          ARG      17.716        59.90000
# 6                           Armenia          ARM      13.308        41.90000
# 7               Antigua and Barbuda          ATG      16.447        63.40000
# 8                         Australia          AUS      13.200        83.00000
# 9                           Austria          AUT       9.400        80.61880
# 10                       Azerbaijan          AZE      18.300        58.70000
# ...

# %%
#multiple
stats[(stats.Birth rate>15) & (stats.Internet users>=30)]
# Out:
#   File "<ipython-input-90-5b5acec2f67b>", line 2
#     stats[(stats.Birth rate>15) & (stats.Internet users>=30)]
#                           ^
# SyntaxError: invalid syntax

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats[stats.Birth rate=="12.877"]
# Out:
#   File "<ipython-input-93-ae96cfc058ab>", line 1
#     stats[stats.Birth rate=="12.877"]
#                          ^
# SyntaxError: invalid syntax

# %%
## accessing individual elements

# .at -- for labels: even integers are treated as labels
# .iat -- for integer location.

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.iat[4,4]
# Out:
# 'High income'

# %%
stats.at[2,'Country Name']
# Out:
# 'Angola'

# %%
# why do we need .at
sub10= stats[::10]
sub10
# Out:
#     Country Name Country Code  Birth rate  Internet users         Income Group
# 0          Aruba          ABW      10.244       78.900000          High income
# 10    Azerbaijan          AZE      18.300       58.700000  Upper middle income
# 20       Belarus          BLR      12.500       54.170000  Upper middle income
# 30        Canada          CAN      10.900       85.800000          High income
# 40    Costa Rica          CRI      15.022       45.960000  Upper middle income
# 50       Ecuador          ECU      21.070       40.353684  Upper middle income
# 60         Gabon          GAB      30.555        9.200000  Upper middle income
# 70     Greenland          GRL      14.500       65.800000          High income
# 80         India          IND      20.291       15.100000  Lower middle income
# 90    Kazakhstan          KAZ      22.730       54.000000  Upper middle income
# 100        Libya          LBY      21.425       16.500000  Upper middle income
# ...

# %%
sub10.iat[10,0]
# Out:
# 'Libya'

# %%
sub10.at[10,'Country Name']
# Out:
# 'Azerbaijan'

# %%
# introduction to seaborn (powerful visualization package)


import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize']=10,8
import warnings
warnings.filterwarnings('ignore')

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# distribution

visl = sns.distplot(stats["Internet users"],bins=5)

# %%
visl = sns.distplot(stats["Birth rate"])

# %%
#box plots

vis2= sns.boxplot(data=stats,x='Income Group',y='Birth rate')

# %%
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
#seaborn gallery

vis3=sns.lmplot(data=stats,x='Internet users',y='Birth rate',fit_reg=False) #lm=linear model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-f643286693fd> in <module>()
#       1 #seaborn gallery
#       2
# ----> 3 vis3=sns.lmplot(data=stats,x='Internet users',y='Birth rate',fit_reg=False) #lm=linear model
#
# NameError: name 'sns' is not defined

# %%
vis4=sns.distplot(stats["Birth rate"])

# %%
vis3=sns.lmplot(data=stats,x='Internet users',y='Birth rate',fit_reg=False,hue='Income Group',size=8,aspect=1)

# %%
#keypad arguements in python

# %%
#marker size
vis3=sns.lmplot(data=stats,x='Internet users',y='Birth rate',fit_reg=False,hue='Income Group',size=5,aspect=1.5,markers='s')

# %%
#marker size changes by scatter_kws
vis3=sns.lmplot(data=stats,x='Internet users',y='Birth rate',fit_reg=False,hue='Income Group',size=5,aspect=1.5,markers='s',scatter_kws={"s":50})

# %%
stats
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 0                             Aruba          ABW      10.244        78.90000
# 1                       Afghanistan          AFG      35.253         5.90000
# 2                            Angola          AGO      45.985        19.10000
# 3                           Albania          ALB      12.877        57.20000
# 4              United Arab Emirates          ARE      11.044        88.00000
# 5                         Argentina          ARG      17.716        59.90000
# 6                           Armenia          ARM      13.308        41.90000
# 7               Antigua and Barbuda          ATG      16.447        63.40000
# 8                         Australia          AUS      13.200        83.00000
# 9                           Austria          AUT       9.400        80.61880
# 10                       Azerbaijan          AZE      18.300        58.70000
# ...
